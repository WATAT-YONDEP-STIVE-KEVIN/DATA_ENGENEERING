# %% [markdown]
# <center><h2>Collecter les données a partir des fichiers</h2></center>

# %%
import pandas as pd
import openpyxl

# %% [markdown]
# <center><h3>Fichiers csv</h3></center>

# %%
data_csv = pd.read_csv("./datas/best_seller_books_of_amazon.csv") #chargement des données

# %%
data_csv.head(5)#Affichages des 5 premieres lignes du jeu de données
# Out:
#                                            Book Name         Author Name  \
# 0  Maths Concept King All Formulas and Theorum | ...    Gagan Pratap Sir
# 1  BlackBook of English Vocabulary May 2024 by Ni...        Nikhil Gupta
# 2  Atomic Habits : the life-changing million-copy...         James Clear
# 3  My First Library: Boxset of 10 Board Books for...  Wonder House Books
# 4  Lucent General Knowledge - New Reduced Price E...         Binay Karna
#
#    Rating    Price
# 0     4.7  ₹239.00
# 1     4.5  ₹299.00
# 2     4.6  ₹476.00
# 3     4.5  ₹399.00
# 4     4.4  ₹209.00

# %%
data_csv.info()#afficher les informations sur les données
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Book Name    400 non-null    object
#  1   Author Name  400 non-null    object
#  2   Rating       400 non-null    float64
#  3   Price        400 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 12.6+ KB

# %% [markdown]
# <center><h3>Fichiers txt</h3></center>

# %%
data_txt = pd.read_csv("./datas/NFLX.txt")

# %%
data_txt.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-02-01  353.859985  365.390015  349.910004  361.989990  361.989990
# 1  2023-02-02  365.160004  368.320007  358.429993  366.890015  366.890015
# 2  2023-02-03  359.079987  379.429993  359.000000  365.899994  365.899994
# 3  2023-02-06  363.640015  368.450012  360.679993  361.480011  361.480011
# 4  2023-02-07  358.510010  364.179993  354.179993  362.950012  362.950012
#
#     Volume
# 0  8005200
# 1  7857000
# 2  9402000
# 3  4994900
# 4  6289400

# %% [markdown]
# <center><h3>Fichiers xlsx</h3></center>

# %%
data_xlsx = pd.read_excel("./datas/DimCustomer.xlsx")

# %%
data_xlsx.head(5)
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle  BirthDate MaritalStatus  ... EnglishOccupation  \
# 0     Yang      False 1971-10-06             M  ...      Professional
# 1    Huang      False 1976-05-10             S  ...      Professional
# 2   Torres      False 1971-02-09             M  ...      Professional
# 3      Zhu      False 1973-08-14             S  ...      Professional
# 4  Johnson      False 1979-08-05             S  ...      Professional
#
#   SpanishOccupation FrenchOccupation  HouseOwnerFlag  NumberCarsOwned  \
# ...

# %%
data_json = pd.read_json("./datas/banksdata.json")

# %%
data_json.head(5)
# Out:
#    Rank                                Bank Name  \
# 0     1  Industrial and Commercial Bank of China
# 1     2               Agricultural Bank of China
# 2     3                  China Construction Bank
# 3     4                            Bank of China
# 4     5                           JPMorgan Chase
#
#   Total Assets (2023, US$ billion)
# 0                         6,303.44
# 1                         5,623.12
# 2                         5,400.28
# 3                         4,578.28
# 4                         3,875.39
